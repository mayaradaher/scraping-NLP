# %% [markdown]
# ### Web scraper to scrape indeed.com page job listings

# %%
import cloudscraper
from bs4 import BeautifulSoup
import pandas as pd

# %%
# function to Extract the Html from indeed
def Extract(page=0):
    scraper = cloudscraper.create_scraper(delay=10, browser='chrome')
    url = f'https://br.indeed.com/jobs?q=Cientista%20de%20Dados&start={page}' # br=Brazil, Cientista de Dados=job title
    r = scraper.get(url)
    soup = BeautifulSoup(r.content,'html.parser')
    return soup, r
print(Extract()[1])
# Out:
# <Response [200]>

# %%
# function to Transform the html we extracted into data
def Transform(soup):
    divs = soup.find_all('div', {'class': 'job_seen_beacon'}) # locating tags and classes.(jobs, salaries...)
    for div in divs :
        try:
            company = div.find('span', {'class': 'companyName'}).text.strip() # extracting company name
        except:
            company= ''

        try:
            job_title = div.find('h2', attrs={'class':'jobTitle'}).text.strip() # extracting job title
        except:
            job_title = ''

        try:
            salary = div.find('div', {'class': ['attribute_snippet', 'estimated-salary']}).text.strip() # extracting salary
        except:
            salary = ''

        try:
            location = div.find('div', {'class': 'companyLocation'}).text.strip() # extracting location
        except:
            location = ''

        try:
            rating = div.find('span', attrs={'class': 'ratingNumber'}).text.strip() # extracting rating
        except:
            rating = ''

        try:
            summary = div.find('div', attrs={'class': 'job-snippet'}).text.strip() # extracting summary
        except:
            summary = ''
        # grab the results and putting it into a dictionary
        job = {
            'Título': job_title,
            'Empresa' : company,
            'Local' : location,
            'Salário ' : salary,
            'Avaliação' : rating,
            'Descrição' : summary
        }
        joblist.append(job) # appending the data to a list to iterate through it
    return

joblist = []

# %%
for pages in range(0,35): # run throw the first 15 pages
    info=Extract(pages)[0]
    Transform(info)

# %%
# creating a dataframe from the results
df = pd.DataFrame(joblist)
df
# Out:
#                                                 Título        Empresa  \
# 0                     PESSOA CIENTISTA DE DADOS JÚNIOR         Serasa
# 1                                   Cientista de Dados         BWTECH
# 2          Tecnologia | Cientista de Dados e Analytics          Cielo
# 3                                Cientista de Dados Jr      Maxxidata
# 4                                 Cientista de Dados I        Martins
# ..                                                 ...            ...
# 632  Produto | Analista de Dados Junior | Vaga Afir...           Gupy
# 633                          Cientista de Dados Sênior     marketdata
# 634                            Analista de Dados de BI         Firjan
# 635                                 Cientista de Dados  Keyrus Brazil
# 636       Analista de dados - Databricks (Vaga Remota)        Nórdica
#
#                                  Local                     Salário  Avaliação  \
# 0                        São Paulo, SP               Tempo integral       4,3
# 1                   Belo Horizonte, MG
# 2                          Home office                                    4,2
# 3                          Home office
# 4                          Home office                                    3,5
# ..                                 ...                          ...       ...
# 632                        Home office                 Meio período
# 633       Home office in São Paulo, SP
# 634  Home office in Rio de Janeiro, RJ  R$ 5.000 - R$ 7.000 por mês       4,4
# 635                      São Paulo, SP
# 636       Home office in São Paulo, SP
#
#                                              Descrição
# 0    Somos formados por gente inquieta, inconformad...
# 1    Tratamento de dados em cenários de big data;\n...
# 2    Ferramentas de visualização de dados - Tableau...
# 3    Experiência com pipeline de dados no AWS ou GC...
# 4    Conhecimento em Linguagens de programação de a...
# ..                                                 ...
# 632  Garantir a qualidade do dado disponibilizado e...
# 633  Vale Refeição (inclusive no mês das férias).\n...
# 634  Conhecimento em SQL, data warehouse, modelagem...
# 635  Desempenhar papel de liderança no time.\nConhe...
# 636  Conhecimento em engenharia de dados;\nParticip...
#
# [637 rows x 6 columns]

# %%
df.to_excel('data/indeed_jobs.xlsx', sheet_name='Cientista de Dados')
